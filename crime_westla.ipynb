# %%
import pandas as pd
import numpy as np

# %%
# Store filepath in a variable
crime_all = "Resources/Crime_Data_from_2020_to_Present.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
all_crime_df = pd.read_csv(crime_all)

# %%
all_crime_df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 712809  230804266  01/08/2023 12:00:00 AM  01/08/2023 12:00:00 AM      1030
# 712810  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 712811  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 712812  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 712813  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
# ...

# %%
all_crime_df["AREA NAME"].value_counts()
# Out:
# Central        47756
# 77th Street    45154
# Pacific        41306
# Southwest      40023
# Hollywood      38196
# Southeast      36572
# Olympic        35734
# N Hollywood    35551
# Newton         35404
# Wilshire       33682
# Rampart        33016
# West LA        32737
# Northeast      30981
# Van Nuys       30124
# West Valley    29832
# Harbor         29599
# Devonshire     28809
# Topanga        28799
# Mission        28537
# Hollenbeck     26907
# Foothill       24095
# Name: AREA NAME, dtype: int64

# %%
# create df with only data from a specific region
west_la_df = pd.DataFrame(all_crime_df.loc[all_crime_df["AREA NAME"] == "West LA", :])
west_la_df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 28      200815333  10/15/2020 12:00:00 AM  10/15/2020 12:00:00 AM      2000
# 31      210816993  11/24/2021 12:00:00 AM  04/28/2020 12:00:00 AM       100
# 39      200810920  06/20/2020 12:00:00 AM  06/20/2020 12:00:00 AM      1000
# 58      200811087  06/24/2020 12:00:00 AM  06/23/2020 12:00:00 AM      2200
# 70      200812213  07/23/2020 12:00:00 AM  06/22/2020 12:00:00 AM      2005
# ...           ...                     ...                     ...       ...
# 712747  230805552  02/02/2023 12:00:00 AM  02/02/2023 12:00:00 AM      1800
# 712755  230806046  02/18/2023 12:00:00 AM  02/18/2023 12:00:00 AM      1930
# 712798  230804108  01/03/2023 12:00:00 AM  01/02/2023 12:00:00 AM      1130
# 712807  230806871  03/03/2023 12:00:00 AM  03/02/2023 12:00:00 AM       620
# 712809  230804266  01/08/2023 12:00:00 AM  01/08/2023 12:00:00 AM      1030
#
#         AREA AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# ...

# %%
west_la_df.count()
# Out:
# DR_NO             32737
# Date Rptd         32737
# DATE OCC          32737
# TIME OCC          32737
# AREA              32737
# AREA NAME         32737
# Rpt Dist No       32737
# Part 1-2          32737
# Crm Cd            32737
# Crm Cd Desc       32737
# Mocodes           29715
# Vict Age          32737
# Vict Sex          29779
# Vict Descent      29779
# Premis Cd         32737
# Premis Desc       32729
# Weapon Used Cd     7704
# Weapon Desc        7704
# Status            32737
# Status Desc       32737
# Crm Cd 1          32736
# Crm Cd 2           1935
# Crm Cd 3             41
# Crm Cd 4              2
# LOCATION          32737
# Cross Street       3273
# LAT               32737
# LON               32737
# dtype: int64

# %%
#drop all unnecessary columns
clean_westla_df = west_la_df.loc[:, ["Date Rptd","DATE OCC", "TIME OCC", "AREA NAME", "Crm Cd Desc",
                                      "Vict Age", "LOCATION", "LAT", "LON"]]
clean_westla_df
# Out:
#                      Date Rptd                DATE OCC  TIME OCC AREA NAME  \
# 28      10/15/2020 12:00:00 AM  10/15/2020 12:00:00 AM      2000   West LA
# 31      11/24/2021 12:00:00 AM  04/28/2020 12:00:00 AM       100   West LA
# 39      06/20/2020 12:00:00 AM  06/20/2020 12:00:00 AM      1000   West LA
# 58      06/24/2020 12:00:00 AM  06/23/2020 12:00:00 AM      2200   West LA
# 70      07/23/2020 12:00:00 AM  06/22/2020 12:00:00 AM      2005   West LA
# ...                        ...                     ...       ...       ...
# 712747  02/02/2023 12:00:00 AM  02/02/2023 12:00:00 AM      1800   West LA
# 712755  02/18/2023 12:00:00 AM  02/18/2023 12:00:00 AM      1930   West LA
# 712798  01/03/2023 12:00:00 AM  01/02/2023 12:00:00 AM      1130   West LA
# 712807  03/03/2023 12:00:00 AM  03/02/2023 12:00:00 AM       620   West LA
# 712809  01/08/2023 12:00:00 AM  01/08/2023 12:00:00 AM      1030   West LA
#
# ...

# %%
clean_westla_df["Crm Cd Desc"].value_counts()
# Out:
# BURGLARY                                     3454
# BURGLARY FROM VEHICLE                        2546
# THEFT OF IDENTITY                            2494
# VEHICLE - STOLEN                             2404
# BATTERY - SIMPLE ASSAULT                     2224
#                                              ...
# HUMAN TRAFFICKING - COMMERCIAL SEX ACTS         1
# BIKE - ATTEMPTED STOLEN                         1
# BOAT - STOLEN                                   1
# CONTRIBUTING                                    1
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE       1
# Name: Crm Cd Desc, Length: 109, dtype: int64

# %%
top5_westla_crime = clean_westla_df["Crm Cd Desc"].value_counts().head(5)
top5_westla_crime
# Out:
# BURGLARY                    3454
# BURGLARY FROM VEHICLE       2546
# THEFT OF IDENTITY           2494
# VEHICLE - STOLEN            2404
# BATTERY - SIMPLE ASSAULT    2224
# Name: Crm Cd Desc, dtype: int64

# %%
clean_westla_df.dtypes
# Out:
# Date Rptd       object
# DATE OCC        object
# TIME OCC         int64
# AREA NAME       object
# Crm Cd Desc     object
# Vict Age         int64
# LOCATION        object
# LAT            float64
# LON            float64
# dtype: object

# %%
#df['Date']= pd.to_datetime(df['Date'])
clean_westla_df["DATE OCC"] = pd.to_datetime(clean_westla_df["DATE OCC"])
clean_westla_df
# Out:
#                      Date Rptd   DATE OCC  TIME OCC AREA NAME  \
# 28      10/15/2020 12:00:00 AM 2020-10-15      2000   West LA
# 31      11/24/2021 12:00:00 AM 2020-04-28       100   West LA
# 39      06/20/2020 12:00:00 AM 2020-06-20      1000   West LA
# 58      06/24/2020 12:00:00 AM 2020-06-23      2200   West LA
# 70      07/23/2020 12:00:00 AM 2020-06-22      2005   West LA
# ...                        ...        ...       ...       ...
# 712747  02/02/2023 12:00:00 AM 2023-02-02      1800   West LA
# 712755  02/18/2023 12:00:00 AM 2023-02-18      1930   West LA
# 712798  01/03/2023 12:00:00 AM 2023-01-02      1130   West LA
# 712807  03/03/2023 12:00:00 AM 2023-03-02       620   West LA
# 712809  01/08/2023 12:00:00 AM 2023-01-08      1030   West LA
#
#                                               Crm Cd Desc  Vict Age  \
# 28                               BATTERY - SIMPLE ASSAULT        50
# 31                                      THEFT OF IDENTITY        27
# ...

# %%
clean_westla_df.dtypes
# Out:
# Date Rptd              object
# DATE OCC       datetime64[ns]
# TIME OCC                int64
# AREA NAME              object
# Crm Cd Desc            object
# Vict Age                int64
# LOCATION               object
# LAT                   float64
# LON                   float64
# dtype: object

# %%
central_data = pd.DataFrame({
   'date': pd.date_range('2022-01-01', periods=365),
   'value': range(365)})
central_data
# Out:
#           date  value
# 0   2022-01-01      0
# 1   2022-01-02      1
# 2   2022-01-03      2
# 3   2022-01-04      3
# 4   2022-01-05      4
# ..         ...    ...
# 360 2022-12-27    360
# 361 2022-12-28    361
# 362 2022-12-29    362
# 363 2022-12-30    363
# 364 2022-12-31    364
#
# [365 rows x 2 columns]

# %%
clean_westla_df["year"] = np.nan
clean_westla_df["month"] = np.nan
clean_westla_df["day"] = np.nan
clean_westla_df
# Out:
#                      Date Rptd   DATE OCC  TIME OCC AREA NAME  \
# 28      10/15/2020 12:00:00 AM 2020-10-15      2000   West LA
# 31      11/24/2021 12:00:00 AM 2020-04-28       100   West LA
# 39      06/20/2020 12:00:00 AM 2020-06-20      1000   West LA
# 58      06/24/2020 12:00:00 AM 2020-06-23      2200   West LA
# 70      07/23/2020 12:00:00 AM 2020-06-22      2005   West LA
# ...                        ...        ...       ...       ...
# 712747  02/02/2023 12:00:00 AM 2023-02-02      1800   West LA
# 712755  02/18/2023 12:00:00 AM 2023-02-18      1930   West LA
# 712798  01/03/2023 12:00:00 AM 2023-01-02      1130   West LA
# 712807  03/03/2023 12:00:00 AM 2023-03-02       620   West LA
# 712809  01/08/2023 12:00:00 AM 2023-01-08      1030   West LA
#
#                                               Crm Cd Desc  Vict Age  \
# 28                               BATTERY - SIMPLE ASSAULT        50
# 31                                      THEFT OF IDENTITY        27
# ...

# %%
clean_westla_df['year']= clean_westla_df['DATE OCC'].dt.year
clean_westla_df
# Out:
#                      Date Rptd   DATE OCC  TIME OCC AREA NAME  \
# 28      10/15/2020 12:00:00 AM 2020-10-15      2000   West LA
# 31      11/24/2021 12:00:00 AM 2020-04-28       100   West LA
# 39      06/20/2020 12:00:00 AM 2020-06-20      1000   West LA
# 58      06/24/2020 12:00:00 AM 2020-06-23      2200   West LA
# 70      07/23/2020 12:00:00 AM 2020-06-22      2005   West LA
# ...                        ...        ...       ...       ...
# 712747  02/02/2023 12:00:00 AM 2023-02-02      1800   West LA
# 712755  02/18/2023 12:00:00 AM 2023-02-18      1930   West LA
# 712798  01/03/2023 12:00:00 AM 2023-01-02      1130   West LA
# 712807  03/03/2023 12:00:00 AM 2023-03-02       620   West LA
# 712809  01/08/2023 12:00:00 AM 2023-01-08      1030   West LA
#
#                                               Crm Cd Desc  Vict Age  \
# 28                               BATTERY - SIMPLE ASSAULT        50
# 31                                      THEFT OF IDENTITY        27
# ...

# %%
westla_2020_df = pd.DataFrame(clean_westla_df.loc[clean_westla_df["year"] == 2020, :])
westla_2021_df = pd.DataFrame(clean_westla_df.loc[clean_westla_df["year"] == 2021, :])
westla_2022_df = pd.DataFrame(clean_westla_df.loc[clean_westla_df["year"] == 2022, :])
westla_2020_df
# Out:
#                      Date Rptd   DATE OCC  TIME OCC AREA NAME  \
# 28      10/15/2020 12:00:00 AM 2020-10-15      2000   West LA
# 31      11/24/2021 12:00:00 AM 2020-04-28       100   West LA
# 39      06/20/2020 12:00:00 AM 2020-06-20      1000   West LA
# 58      06/24/2020 12:00:00 AM 2020-06-23      2200   West LA
# 70      07/23/2020 12:00:00 AM 2020-06-22      2005   West LA
# ...                        ...        ...       ...       ...
# 198923  03/03/2023 12:00:00 AM 2020-10-14      1215   West LA
# 199042  04/09/2023 12:00:00 AM 2020-04-01      1200   West LA
# 199114  04/25/2023 12:00:00 AM 2020-01-01       800   West LA
# 199130  04/03/2023 12:00:00 AM 2020-10-12      1340   West LA
# 199131  04/26/2023 12:00:00 AM 2020-09-01       800   West LA
#
#                                               Crm Cd Desc  Vict Age  \
# 28                               BATTERY - SIMPLE ASSAULT        50
# 31                                      THEFT OF IDENTITY        27
# ...

# %%
westla_2021_df
# Out:
#                      Date Rptd   DATE OCC  TIME OCC AREA NAME  \
# 199155  07/04/2021 12:00:00 AM 2021-03-26       930   West LA
# 199161  03/28/2021 12:00:00 AM 2021-03-28      1652   West LA
# 199196  01/11/2021 12:00:00 AM 2021-01-10      1800   West LA
# 199233  04/06/2022 12:00:00 AM 2021-10-21      1555   West LA
# 199317  07/20/2021 12:00:00 AM 2021-07-19      1500   West LA
# ...                        ...        ...       ...       ...
# 408053  04/18/2021 12:00:00 AM 2021-04-16       206   West LA
# 408086  12/31/2021 12:00:00 AM 2021-12-30      1830   West LA
# 408092  09/07/2021 12:00:00 AM 2021-09-07       100   West LA
# 408104  12/21/2021 12:00:00 AM 2021-12-19      2000   West LA
# 408105  08/08/2021 12:00:00 AM 2021-07-08       106   West LA
#
#                                               Crm Cd Desc  Vict Age  \
# 199155  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...        56
# 199161                 THEFT PLAIN - PETTY ($950 & UNDER)        57
# ...

# %%
westla_2020_df["month"] = np.nan

# %%
westla_2020_df['month']= westla_2020_df['DATE OCC'].dt.month
westla_2020_df
# Out:
#                      Date Rptd   DATE OCC  TIME OCC AREA NAME  \
# 28      10/15/2020 12:00:00 AM 2020-10-15      2000   West LA
# 31      11/24/2021 12:00:00 AM 2020-04-28       100   West LA
# 39      06/20/2020 12:00:00 AM 2020-06-20      1000   West LA
# 58      06/24/2020 12:00:00 AM 2020-06-23      2200   West LA
# 70      07/23/2020 12:00:00 AM 2020-06-22      2005   West LA
# ...                        ...        ...       ...       ...
# 198923  03/03/2023 12:00:00 AM 2020-10-14      1215   West LA
# 199042  04/09/2023 12:00:00 AM 2020-04-01      1200   West LA
# 199114  04/25/2023 12:00:00 AM 2020-01-01       800   West LA
# 199130  04/03/2023 12:00:00 AM 2020-10-12      1340   West LA
# 199131  04/26/2023 12:00:00 AM 2020-09-01       800   West LA
#
#                                               Crm Cd Desc  Vict Age  \
# 28                               BATTERY - SIMPLE ASSAULT        50
# 31                                      THEFT OF IDENTITY        27
# ...

# %%
westla_2020_df.sort_values("month")
# Out:
#                     Date Rptd   DATE OCC  TIME OCC AREA NAME  \
# 69641  01/20/2020 12:00:00 AM 2020-01-17      2100   West LA
# 59075  01/28/2020 12:00:00 AM 2020-01-28      1700   West LA
# 13423  01/28/2020 12:00:00 AM 2020-01-27      2200   West LA
# 59104  01/17/2020 12:00:00 AM 2020-01-11       800   West LA
# 64920  01/29/2020 12:00:00 AM 2020-01-25      2300   West LA
# ...                       ...        ...       ...       ...
# 87669  12/28/2020 12:00:00 AM 2020-12-28       944   West LA
# 12219  12/07/2020 12:00:00 AM 2020-12-07      1857   West LA
# 52979  12/05/2020 12:00:00 AM 2020-12-05      1230   West LA
# 53530  12/14/2020 12:00:00 AM 2020-12-05       230   West LA
# 10071  12/30/2020 12:00:00 AM 2020-12-19      1430   West LA
#
#                                              Crm Cd Desc  Vict Age  \
# 69641                                      BIKE - STOLEN        32
# 59075           SHOPLIFTING - PETTY THEFT ($950 & UNDER)         0
# ...

# %%
westla_2020_df.value_counts("Crm Cd Desc")
# Out:
# Crm Cd Desc
# BURGLARY                                                1066
# BURGLARY FROM VEHICLE                                    813
# BATTERY - SIMPLE ASSAULT                                 662
# THEFT OF IDENTITY                                        659
# VEHICLE - STOLEN                                         648
#                                                         ...
# DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $950.01       1
# CONTRIBUTING                                               1
# CHILD PORNOGRAPHY                                          1
# BOAT - STOLEN                                              1
# WEAPONS POSSESSION/BOMBING                                 1
# Length: 92, dtype: int64
